# %% [markdown]
# # Consolidación de la data

# %% [markdown]
# ## Configuración inicial

# %%
# !pip install pyreadstat pyarrow fastparquet
# Out:
# Collecting pyreadstat
#   Downloading pyreadstat-1.3.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.12/dist-packages (18.1.0)
# Collecting fastparquet
#   Downloading fastparquet-2024.11.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# Requirement already satisfied: narwhals>=1.47 in /usr/local/lib/python3.12/dist-packages (from pyreadstat) (2.10.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from pyreadstat) (2.0.2)
# Requirement already satisfied: pandas>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from fastparquet) (2.2.2)
# Requirement already satisfied: cramjam>=2.3 in /usr/local/lib/python3.12/dist-packages (from fastparquet) (2.11.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from fastparquet) (2025.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from fastparquet) (25.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5.0->fastparquet) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5.0->fastparquet) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5.0->fastparquet) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.5.0->fastparquet) (1.17.0)
# Downloading pyreadstat-1.3.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (666 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 666.4/666.4 kB 16.0 MB/s eta 0:00:00
# Downloading fastparquet-2024.11.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 51.2 MB/s eta 0:00:00
# Installing collected packages: pyreadstat, fastparquet
# Successfully installed fastparquet-2024.11.0 pyreadstat-1.3.1

# %%
import pandas as pd
import pyreadstat
import duckdb
import glob
import os
from pathlib import Path

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
raw_path = Path('/content/drive/MyDrive/classification_coding_open_ended_occupational_responses_ENAHO/data/raw')  #'../data/raw'

# %%
preview_300 = pd.read_stata(raw_path / 'enaho01a-2020-2024-300-educacion_p301a.dta', convert_categoricals=False)
# Out:
# /tmp/ipython-input-3476152806.py:1: UnicodeWarning:
# One or more strings in the dta file could not be decoded using utf-8, and
# so the fallback encoding of latin-1 is being used.  This can happen when a file
# has been incorrectly encoded by Stata or some other software. You should verify
# the string values returned are correct.
#   preview_300 = pd.read_stata(raw_path / 'enaho01a-2020-2024-300-educacion_p301a.dta', convert_categoricals=False)

# %%
preview_300.shape
# Out:
# (550874, 8)

# %%
print(preview_300.columns.tolist())
# Out:
# ['id_persona', 'anio', 'conglome', 'vivienda', 'hogar', 'codperso', 'p301a', 'p301a1']

# %%
preview_500 = pd.read_stata(raw_path / 'enaho01a_2020_2024_500_txt.dta', convert_categoricals=False)
# Out:
# /tmp/ipython-input-1912739101.py:1: UnicodeWarning:
# One or more strings in the dta file could not be decoded using utf-8, and
# so the fallback encoding of latin-1 is being used.  This can happen when a file
# has been incorrectly encoded by Stata or some other software. You should verify
# the string values returned are correct.
#   preview_500 = pd.read_stata(raw_path / 'enaho01a_2020_2024_500_txt.dta', convert_categoricals=False)

# %%
print(preview_500.columns.tolist())
# Out:
# ['aÑo', 'mes', 'conglome', 'vivienda', 'hogar', 'codperso', 'ubigeo', 'dominio', 'estrato', 'codinfor', 'p500a', 'p500b', 'p500b1', 'p500c', 'p500d', 'p500d1', 'p500n', 'p500i', 'p501', 'p502', 'p503', 'p504', 'p5041', 'p5042', 'p5043', 'p5044', 'p5045', 'p5046', 'p5047', 'p5048', 'p5049', 'p50410', 'p50411', 'p504a', 'p504b', 'p505', 'p505r4', 'txt505', 'p505b', 'txt505b', 'p506', 'p506r4', 'txt506', 'p507', 'p508', 'p509', 'p510', 'p510a1', 'p510b', 'p5111', 'p5112', 'p5113', 'p5114', 'p5115', 'p5116', 'p5117', 'p5118', 'p5119', 'p51110', 'p51111', 'p51112', 'p511a', 'p512a', 'p512b', 'p513', 'p513a', 'p513b', 'p513c', 
c', 'p55614d', 'p55614e', 'p55616a', 'p55616b', 'p55616c', 'p55616d', 'p55616e', 'p55616a_e', 'p55616b_e', 'p55616c_e', 'p55616d_e', 'p55617a', 'p55617b', 'p55617c', 'p55617d', 'p55617e', 'p55617a_e', 'p55617b_e', 'p55617c_e', 'p55617d_e', 'p55618a', 'p55618b', 'p55618c', 'p55618d', 'p55618e', 'p55618a_e', 'p55618b_e', 'p55618c_e', 'p55618d_e', 'p55619a', 'p55619b', 'p55619c', 'p55619d', 'p55619e', 'p55619a_e', 'p55619b_e', 'p55619c_e', 'p55619d_e', 'p55620a', 'p55620b', 'p55620c', 'p55620d', 'p55620e', 'p55621a', 'p55621b', 'p55621c', 'p55621d', 'p55621e', 'p55622a', 'p55622b', 'p55622c', 'p55622d', 'p55622e', 'p55623a', 'p55623b', 'p55623c', 'p55623d', 'p55623e', 'p55624a', 'p55624b', 'p55624c', 'p55624d', 'p55624e', 'p55625a', 'p55625b', 'p55625c', 'p55625d', 'p55625e', 'p55624a_e', 'p55624b_e', 'p55624c_e', 'p55624d_e', 'p55625a_e', 'p55625b_e', 'p55625c_e', 'p55625d_e', 'p55626a', 'p55626b', 'p55626c', 'p55626d', 'p55626e', 'p55627a', 'p55627b', 'p55627c', 'p55627d', 'p55627e', 'p55628a', 'p55628b', 'p55628c', 'p55628d', 'p55628e', 'p556t1', 'p556t1_e', ' ...

# %% [markdown]
# ## Extraer etiquetas (lbl)

# %%
# Read metadata with content

_, meta1 = pyreadstat.read_dta(raw_path / 'enaho01a_2020_2024_500_txt.dta',
metadataonly=True, encoding='latin1')
vars_1 = ['p207', 'p301a', 'p506r4', 'p507', 'p510', 'p505r4']
labels_1 = {var: meta1.variable_value_labels.get(var, {}) for var in vars_1}

_, meta2 = pyreadstat.read_dta(raw_path / 'enaho01a-2020-2024-300-educacion_p301a.dta', metadataonly=True, encoding='latin1')
vars_2 = ['p301a1']
labels_2 = {var: meta2.variable_value_labels.get(var, {}) for var in vars_2}

# %%
# Dict
labels_dict = {**labels_1, **labels_2}
labels_dict.keys()
# Out:
# dict_keys(['p207', 'p301a', 'p506r4', 'p507', 'p510', 'p505r4', 'p301a1'])

# %%
for var, labels in labels_dict.items():
    print(f"Variable: {var}")
    for code, label in labels.items():
        print(f"  {code}: {label}")
    print("-" * 30)
# Out:
# Variable: p207
#   1: hombre
#   2: mujer
# ------------------------------
# Variable: p301a
#   1: sin nivel
#   2: inicial
#   3: primaria incompleta
#   4: primaria completa
#   5: secundaria incompleta
#   6: secundaria completa
#   7: superior no universitaria incompleta
#   8: superior no universitaria completa
#   9: superior universitaria incompleta
#   10: superior universitaria completa
#   11: maestria/doctorado
#   12: bÃ¡sica especial
# ------------------------------
# Variable: p506r4
#   111: cultivo de cereales (excepto arroz), legumbres y semillas  oleaginosas
#   112: cultivo de arroz
#   113: cultivo de vegetales y melones, raÃ­ces y tubÃ©rculos
#   114: cultivo de  caÃ±a de  azÃºcar
#   115: cultivo de tabaco
#   116: cultivo de fibras
#   119: cultivo de otros productos  no perennes
#   121: cultivo de uvas
#   4774: venta al por menor  de artÃ­culos de segunda mano
#   4781: venta al por menor de alimentos, bebidas y productos del tabaco en puestos de venta y mercados
#   4782: venta al por menor de productos textiles, prendas de vestir y calzado en puestos de venta y mercados
#   4789: venta al por menor de otros productos en puestos de venta y mercados
#   4791: venta al por menor a travÃ©s de pedido por correo o internet
#   4799: otros tipos de venta al por menor no realizada en almacenes, puestos de venta o mercados
#   4911: transporte de pasajeros por vÃ­a fÃ©rrea
#   4912: transporte de carga por vÃ­a fÃ©rrea
#   4921: transporte terrestre de pasajeros de Ã¡reas urbanas y suburbanas
#   4922: otros tipos de transporte terrestre de pasajeros
#   4923: transporte de carga por carretera
#   4930: transporte por tuberÃ­as
#   5011: transporte marÃ­timo y de cabotaje de pasajeros
#   5012: transporte marÃ­timo y de cabotaje de carga
#   5021: transporte de pasajeros por vÃ­as de navegaciÃ³n interiores
#   5022: transporte de carga por vÃ­as de navegaciÃ³n interiores
#   5110: transporte de pasajeros por vÃ­a aÃ©rea
#   5120: transporte de carga por vÃ­a aÃ©rea
#   5210: depÃ³sito y almacenamiento
#   5221: actividades de servicios relacionadas con el transporte terrestre
#   5222: actividades de servicios relacionadas con el transporte acuÃ¡tico
#   5223: actividades de servicios relacionadas con el transporte aÃ©reo
#   5224: manipulaciÃ³n de la carga
#   5229: otras actividades complementarias de transporte
#   5310: correo
#   5320: servicio de mensajerÃ­a
#   5510: actividades de alojamiento de corto plazo
#   5520: parques de caravanas, parques de remolques, campamentos de recreo y camping
#   5590: otros tipos de alojamiento
#   5610: restaurantes y servicios mÃ³viles de alimentaciÃ³n
#   5621: provisiÃ³n de comidas preparadas
#   5629: otras actividades del servicio de alimentaciÃ³n
#   5630: actividades vinculadas al servicio de bebidas
#   5811: ediciÃ³n de libros
#   5812: ediciÃ³n de directorios y listas de correo
#   5813: ediciÃ³n de periÃ³dicos, revistas y publicaciones periÃ³dicas
#   5819: otras actividades de ediciÃ³n
#   5820: ediciÃ³n de programas informÃ¡ticos
#   5911: actividades de producciÃ³n de pelÃ­culas, videocintas y programas de televisiÃ³n
#   5912: actividades posteriores de la producciÃ³n de pelÃ­culas, videocintas y programas de televisiÃ³n
#   5913: actividades de distribuciÃ³n de pelÃ­culas, videocintas y programas de televisiÃ³n
#   5914: actividades de proyecciÃ³n de pelÃ­culas
#   5920: actividades de grabaciÃ³n de sonido y ediciÃ³n de mÃºsica
#   6010: difusiÃ³n de radio
#   6020: actividades de programaciÃ³n y difusiÃ³n por televisiÃ³n
#   6110: actividades de telecomunicaciones por cable
#   6120: actividades de telecomunicaciones inalÃ¡mbricas
#   6130: actividades de telecomunicaciones por satÃ©lite
#   6190: otras actividades de telecomunicaciÃ³n
#   6201: actividades de programaciÃ³n informÃ¡tica
#   6202: actividades de consultorÃ­a informÃ¡tica y  administraciÃ³n de medios informÃ¡ticos
#   6209: otras actividades de tecnologÃ­a de la informaciÃ³n y servicios informÃ¡ticos
#   6311: procesamiento de datos, hospedaje y actividades conexas
#   6312: portales web
#   6391: actividades de agencias de noticias
#   6399: otras actividades de servicios de informaciÃ³n n.c.p.
#   6411: banca central
#   6419: otros tipos de intermediaciÃ³n monetaria
#   6420: actividades de sociedades de cartera (holding)
#   6430: fideicomisos, fondos y otras fuentes de financiamiento
#   6491: arrendamiento financiero
#   6492: otros tipos de actividades crediticias
#   6499: otras actividades de servicios financieros, excepto seguros y fondo de pensiones n.c.p.
#   6511: seguros de vida
#   6512: otros tipos de seguros
#   6520: reaseguros
#   6530: fondo de pensiones
#   6611: administraciÃ³n de mercados financieros
#   6612: actividades bursÃ¡tiles y de tramitaciÃ³n de contratos de productos bÃ¡sicos
#   6619: otras actividades auxiliares a las actividades de servicios financieros
#   6621: evaluaciÃ³n de riesgos y daÃ±os
#   6622: actividades de los agentes y corredores de seguros
#   6629: otras actividades auxiliares de seguros y fondo de pensiones
#   6630: actividades de administraciÃ³n de fondos
#   6810: actividades inmobiliarias realizadas con bienes propios o arrendados
#   6820: actividades inmobiliarias realizadas a cambio de un retribuciÃ³n o por contrato
#   6910: actividades jurÃ­dicas
#   6920: actividades de contabilidad, tenedurÃ­a de libros y auditorÃ­as; asesoramiento en materia de impuestos
#   7010: actividades de oficinas centrales
#   7020: actividades de asesoramiento sobre administraciÃ³n de empresas
#   7110: actividades de arquitectura e ingenierÃ­a y actividades conexas de asesoramiento tÃ©cnico
#   7120: ensayos y anÃ¡lisis tÃ©cnicos
#   7210: investigaciÃ³n y desarrollo experimental en el campo de las ciencias naturales y la ingenierÃ­a
#   7220: investigaciÃ³n y desarrollo experimental en el campo de las ciencias sociales y las humanidades
#   7310: publicidad
#   7320: investigaciÃ³n de mercados y encuestas de opiniÃ³n pÃºblica
#   7410: actividades especializadas de diseÃ±o
#   7420: actividades fotogrÃ¡ficas
#   7490: otras actividades profesiones, cientÃ­ficas y tÃ©cnicas n.c.p.
#   7500: actividades veterinarias
#   7710: alquiler y arrendamiento de vehÃ­culos automotores
#   7721: alquiler y arrendamiento de equipos recreativos y deportivos
#   7722: alquiler de cintas de video y discos
#   7729: alquiler de otros bienes personales y enseres domÃ©sticos
#   7730: alquiler y arrendamiento de otros tipos de maquinarias, equipos y bienes tangibles
#   7740: arrendamiento de la propiedad intelectual y productos similares, excepto derechos de autor
#   7810: actividades de agencias de colocaciÃ³n de empleo
#   7820: actividades de agencias de trabajo temporal
#   7830: otros suministros de recursos humanos
#   7911: actividades de agencias de viajes
#   7912: actividades de operadores turÃ­sticos
#   7990: otros servicios de reserva y actividades relacionadas
#   8010: actividades de seguridad privada
#   8020: actividades de servicio de sistemas de seguridad
#   8030: actividades de investigaciÃ³n
#   8110: actividades combinadas de apoyo a instalaciones
#   8121: limpieza general de edificios
#   8129: otras actividades de limpieza en edificios e industrias
#   8130: actividades de servicio de mantenimiento y cuidado de jardines y Ã¡reas verdes
#   8211: actividades combinadas de prestaciÃ³n de servicios administrativos de oficina
#   8219: fotocopiado, preparaciÃ³n de documentos y otras actividades especializadas de apoyo a oficinas
#   8220: actividades de las centrales telefÃ³nicas
#   8230: organizaciÃ³n de convenciones y eventos comerciales
#   8291: actividades de agencias de cobranza y oficinas de crÃ©dito
#   8292: actividades de embalaje
#   2: trabajador independiente
#   3: empleado
#   4: obrero
#   5: trabajador familiar no remunerado
#   6: trabajador del hogar
#   7: otro
# ------------------------------
# Variable: p510
#   1: fuerzas armadas, policÃ­a nacional del perÃº (militares)
#   2: administraciÃ³n pÃºblica
#   3: empresa pÃºblica
#   5: empresas especiales de servicios (service)
#   6: empresa o patrono privado
#   7: otra
# ------------------------------
# Variable: p505r4
#   111: oficiales del ejÃ©rcito
#   112: oficiales de la marina de guerra
#   113: oficiales de la fuerza aÃ©rea
#   120: oficiales de la fuerzas policiales
#   211: suboficiales del ejÃ©rcito
#   212: suboficiales de la marina de guerra
#   213: suboficiales de la fuerza aÃ©rea
#   220: suboficiales de la policÃ­a nacional
#   311: tÃ©cnicos del ejÃ©rcito
#   312: tÃ©cnicos de la marina de guerra
#   313: tÃ©cnicos de la fuerza aÃ©rea
#   320: tÃ©cnicos de la fuerzas policiales
#   1111: miembros del poder ejecutivo excepto jefes de pequeÃ±as poblaciones
#   1112: miembros del poder legislativo
#   1113: miembros del poder judicial
#   1114: directivos de la administraciÃ³n pÃºblica
#   1115: jefes de comunidades indÃ­genas, etnias especiales y otras pequeÃ±as poblaciones
#   1121: directores generales del sector privado agropecuario, la caza y la silvicultura
#   1122: directores generales del sector privado de la piscicultura y la pesca
#   1131: directores generales del sector privado de la industria manufacturera
#   1132: directores generales del sector privado de explotaciones mineras, petrÃ³leo y gas
#   1133: directores generales del sector privado de la construcciÃ³n
#   1134: directores generales de servicios de abastecimiento, distribuciÃ³n, transporte y afines
#   1141: directores generales del sector privado del servicio de alojamiento
#   1142: directores generales del sector privado del servicio de restaurante
#   1143: directores generales del sector privado del comercio al por mayor
#   1144: directores generales del sector privado del comercio al por menor
#   1150: directores generales del sector privado de servicios de tecnologÃ­a de la informaciÃ³n y las comunicaciones (tic)
#   1161: directores generales del sector privado que presentan servicios de cuidados infantiles
#   1162: directores generales de centros culturales y entretenimiento
#   1163: directores generales del sector privado que prestan servicios de salud
#   1164: directores generales del sector privado que prestan servicios del adulto mayor
#   1165: directores generales del sector privado que presenta servicios de bienestar social
#   1166: directores generales del sector privado que prestan servicios de educaciÃ³n
#   1167: directores generales del sector privado que prestan servicios financieros y de seguros
#   1169: otros directores generales del sector privado que prestan servicios profesionales
#   1171: dirigentes de organizaciones polÃ­ticas
#   1172: dirigentes de organizaciones gremiales
#   1173: dirigentes de organizaciones que presentan un interÃ©s especial
#   1211: directores de administraciÃ³n financiera, de presupuesto y/o contabilidad
#   1212: directores de recursos humanos y/o relaciones laborales
#   1213: directores de polÃ­ticas y planificaciÃ³n
#   1219: otros directores de administraciÃ³n y servicios
#   1221: directores de ventas y comercializaciÃ³n
#   1222: directores de publicidad y relaciones pÃºblicas.
#   1223: directores de investigaciÃ³n y desarrollo
#   1311: directores y gerentes de producciÃ³n agropecuaria y silvicultura
#   1312: directores y gerentes de producciÃ³n de piscicultura y pesca
#   1321: directores y gerentes de industrias manufactureras
#   1322: directores y gerentes de empresas de explotaciones mineras
#   1323: directores y gerentes de empresas de construcciÃ³n
#   1324: directores y gerentes de empresas de transporte
#   1325: directores y gerentes de producciÃ³n y suministro de petrÃ³leo y gas
#   1326: directores y gerentes en generaciÃ³n y provisiÃ³n de energÃ­a elÃ©ctrica y agua
#   1330: directores y gerentes de servicios de tecnologÃ­a de la informaciÃ³n y las comunicaciones
#   1341: directores y gerentes de empresas que prestan servicios de cuidados infantiles
#   1342: directores y gerentes de empresas que prestan servicios de salud
#   1343: directores de servicios del cuidado del adulto mayor
#   1344: directores de empresas que ofrecen servicios sociales
#   1345: directores de servicios en centros de enseÃ±anza y capacitaciÃ³n
#   1346: gerentes de sucursales de bancos, de servicios financieros y de seguros
#   1411: gerentes de hoteles y establecimientos similares que proveen servicios de alojamiento
#   1412: gerentes de restaurantes, bares y afines
#   1421: gerentes de abastecimiento y distribuciÃ³n
#   1422: gerentes de comercios al por mayor y al por menor
#   1491: directores y gerentes de centros deportivos, de esparcimiento y entretenimientos
#   1492: directores y gerentes de centros culturales
#   1499: otros gerentes de servicios
#   2111: fÃ­sicos y astrÃ³nomos
#   2112: meteorÃ³logos
#   2113: quÃ­micos
#   2114: geÃ³logos y geofÃ­sicos
#   2120: matemÃ¡ticos, actuarios y estadÃ­sticos
#   2131: biÃ³logos, botÃ¡nicos, zoÃ³logos y afines
#   2132: agrÃ³nomos y afines
#   2133: profesionales de la protecciÃ³n medioambiental
#   2141: ingenieros industriales y de producciÃ³n
#   2142: ingenieros civiles
#   2143: ingenieros medioambientales
#   2144: ingenieros mecÃ¡nicos
#   2145: ingenieros quÃ­micos
#   2146: ingenieros de minas, metalÃºrgicos y afines
#   2149: otros ingenieros
#   2151: ingenieros electricistas
#   2152: ingenieros electrÃ³nicos
#   2153: ingenieros en telecomunicaciones
#   2161: arquitectos
#   2162: arquitectos paisajistas
#   2163: diseÃ±adores de productos y de prendas
#   2164: urbanistas e ingenieros de trÃ¡nsito
#   2165: cartÃ³grafos y agrimensores
#   2166: diseÃ±adores grÃ¡ficos y multimedia
#   2211: mÃ©dicos generales
#   2212: mÃ©dicos especialistas
#   2221: profesionales de enfermerÃ­a
#   2222: profesionales de parterÃ­a
#   2230: profesionales de medicina tradicional y alternativa
#   2240: veterinarios
#   2251: dentistas
#   2252: farmacÃ©uticos
#   2253: profesionales de la salud y la higiene laboral y ambiental
#   2254: fisioterapeutas
#   2255: dietistas y nutricionistas
#   2256: audiÃ³logos y logopedas
#   2257: optometristas
#   2259: otros profesionales de la salud
#   2311: profesores de universidades
#   2312: profesores de educaciÃ³n tÃ©cnico productivos
#   2320: profesores de formaciÃ³n profesional
#   2330: profesores de enseÃ±anza secundaria
#   2341: profesores de enseÃ±anza primaria
#   2342: profesores de enseÃ±anza inicial
#   2351: especialistas en mÃ©todos pedagÃ³gicos
#   2352: educadores para necesidades especiales
#   2353: instructores en tecnologÃ­a de la informaciÃ³n
#   2359: otros profesionales de la enseÃ±anza
#   2411: contadores
#   2412: analistas y asesores financieros y de inversiones
#   2421: analistas de gestiÃ³n y organizaciÃ³n
#   2422: especialistas en polÃ­ticas de administraciÃ³n
#   2423: especialistas en polÃ­ticas y servicios de personal y afines
#   4211: cajeros de bancos y afines
#   4212: empleados de ventas de apuestas y de salas de juego
#   4213: empleados de casas de empeÃ±o y de prÃ©stamo
#   4214: cobradores y afines
#   4221: empleados de agencias de viajes
#   4222: empleados de centros de llamadas
#   4223: empleados de ventanillas de informes
#   4224: recepcionistas
#   4225: entrevistadores de encuestas y de investigaciones de mercados
#   4229: otros empleados de servicios de informaciÃ³n al cliente
#   4311: empleados de contabilidad y cÃ¡lculo de costos
#   4312: empleados de servicios estadÃ­sticos, financieros y de seguros
#   4313: empleados encargados de las nÃ³minas
#   4321: empleados de control de abastecimiento e inventario
#   4322: empleados de servicios de apoyo a la producciÃ³n
#   4323: empleados de servicios de transporte
#   4411: empleados de bibliotecas
#   4412: empleados de servicios de correos
#   4413: codificadores de datos, correctores de pruebas de imprenta y afines
#   4414: escribientes pÃºblicos y afines
#   4415: empleados de archivos
#   4416: empleados del servicio de personal
#   4417: auxiliares en la administraciÃ³n, contabilidad, derecho y afines
#   4419: otro personal de apoyo administrativo
#   5111: auxiliares de vuelo, camareros de aviÃ³n y barco
#   5112: revisores de los transportes terrestres
#   5113: guÃ­as de turismo
#   5120: cocineros
#   5131: camareros de mesas
#   5132: camareros de barra
#   5141: peluqueros
#   5142: especialistas en tratamientos de belleza y afines
#   5161: astrÃ³logos, adivinadores y afines
#   5162: personal de pompas fÃºnebres y embalsamadores
#   5163: cuidadores de animales
#   5164: instructores de manejo de auto
#   5165: modelos de moda, arte y publicidad
#   5169: otros trabajadores de servicios personales
#   5211: vendedores mayoristas
#   5212: vendedores minoristas en tiendas y establecimientos (excepto kioscos y mercados)
#   5213: vendedores en kiosco fijo y puestos de mercado
#   5221: supervisores de comercio al por mayor
#   5222: supervisores de comercio al por menor
#   5223: asistentes de venta en tiendas y almacenes
#   5230: cajeros y expendedores de billetes (excepto cajeros de banco)
#   5241: demostradores, degustadores y reponedores
#   5242: vendedores puerta a puerta
#   5243: vendedores por telÃ©fono
#   5244: expendedores de gasolineras
#   5245: vendedores de comidas en mostrador
#   5249: otros vendedores
#   5311: cuidadores de niÃ±os en instituciones
#   5312: auxiliares de maestros
#   5321: trabajadores en el cuidado de personas en instituciones
#   5322: trabajadores en el cuidado de personas a domicilio
#   5329: otros trabajadores en el cuidado de personas en servicios de salud
#   5411: bomberos
#   5412: policÃ­as municipales
#   5413: guardianes de prisiÃ³n
#   5414: guardias de protecciÃ³n en establecimiento
#   5419: otro personal de los servicios de protecciÃ³n
#   6111: agricultores y trabajadores calificados de cultivos extensivos
#   6112: agricultores y trabajadores calificados de plantaciones de Ã¡rboles y arbustos
#   6113: agricultores y trabajadores calificados de huertas, invernaderos, viveros y jardines
#   6114: agricultores y trabajadores calificados de cultivos mixtos (agrÃ­colas, pecuarios y forestales)
#   6121: criadores y trabajadores calificados de ganado
#   6122: avicultores y trabajadores calificados de la avicultura
#   6123: apicultores y sericultores y trabajadores calificados de la apicultura y la sericultura
#   6129: otros criadores y trabajadores pecuarios calificados en la crÃ­a de animales para el mercado
#   6130: productores y trabajadores calificados de explotaciones agropecuarias mixtas cuya producciÃ³n se destina al mercado
#   7432: fabricantes y afinadores de instrumentos musicales
#   7511: matarifes y trabajadores en la elaboraciÃ³n de productos de carne, pescados y afines
#   7512: trabajadores en la elaboraciÃ³n de harinas (excepto harina de pescado)
#   7513: panaderos, pasteleros y confiteros
#   7514: trabajadores en la elaboraciÃ³n de productos lÃ¡cteos.
#   7515: trabajadores en la elaboraciÃ³n y conservaciÃ³n de productos elaborados a base de frutas, legumbres, verduras y afines.
#   7516: catadores y clasificadores de alimentos y bebidas
#   7517: preparadores y elaboradores de tabaco y sus derivados
#   7518: trabajadores de la preparaciÃ³n de bebidas alcohÃ³licas y refrescos
#   7519: otros trabajadores de la preparaciÃ³n de alimentos, bebidas y productos de tabaco
#   8111: mineros y operadores de instalaciones mineras
#   8112: operadores de instalaciones de procesamiento de minerales y rocas
#   8113: perforadores y sondistas de pozos de petrÃ³leo y gas, bombeo y distribuciÃ³n de agua
#   8114: operadores de mÃ¡quinas para fabricar cemento y otros productos minerales
#   8121: operadores de instalaciones de procesamiento de metales
#   8122: operadores de mÃ¡quinas pulidoras, galvanizadoras y recubridoras de metales
#   8131: operadores de plantas y mÃ¡quinas de productos quÃ­micos
#   8132: operadores de mÃ¡quinas para fabricar productos fotogrÃ¡ficos
#   8133: operadores de mÃ¡quinas para el tratamiento de agua
#   8134: operadores de mÃ¡quinas para la perforaciÃ³n de pozos y refinaciÃ³n del petrÃ³leo y gas
#   8141: operadores de mÃ¡quinas para fabricar productos de caucho
#   8142: operadores de mÃ¡quinas para fabricar productos de material plÃ¡stico
#   8151: operadores de mÃ¡quinas de preparaciÃ³n de fibras, hilado y devanado
#   8152: operadores de telares y otras mÃ¡quinas tejedoras
#   8153: operadores de mÃ¡quinas de coser (industrial)
#   8154: operadores de mÃ¡quinas de lavado, blanqueamiento, teÃ±ido, estampado y acabado de productos textiles
#   8155: operadores de mÃ¡quinas de tratamiento de pieles y cueros
#   8156: operadores de mÃ¡quinas para la fabricaciÃ³n de calzado y afines
#   8159: otros operadores de mÃ¡quinas para fabricar productos textiles y artÃ­culos de piel y cuero
# ...
#   342126: finanzas
#   342136: gestion tributaria
#   351016: derecho
#   351026: derecho corporativo
#   351036: derecho empresarial
#   351046: derecho del mar y servicios aduaneros
#   351056: derecho y ciencias politicas (se incluye la carrera de derecho y ciencia política)
#   352015: analisis politico
#   352016: ciencia politica
#   352026: ciencia politica y gobierno
#   411016: biologia
#   411026: biologia en acuicultura
#   411036: biologia marina y econegocios
#   411046: biologia y microbiologia
#   411056: biotecnologia
#   411066: botanica
#   411076: ciencias biologicas
#   411086: genetica y biotecnologia
#   411096: ingeniería biotecnologica
#   411106: microbiologia
#   411116: microbiologia y parasitologia
#   412015: zootecnia
#   412016: ingeniería zootecnia (se incluye la carrera de ing de zootecnia, ingeniería zootécnica e ingeniería de zootecnista)
#   412026: zootecnia
#   413015: hidrografia y navegacion
#   414015: meteorologia
#   421016: ciencias fisico matemática (incluye la carrera de físico  matemáticas)
#   421026: fisica
#   421036: fisica aplicada
#   421046: ingeniería fisica
#   422015: analisis quimico
#   422016: ingeniería de procesos quimicos y metalurgicos
#   422025: quimica industrial
#   422026: ingeniería quimica
#   422035: tecnologia de analisis quimico
#   422036: quimica
#   423016: geologia
#   423026: geologia geotecnia
#   423036: ingeniería de geologia - geotecnia
#   423046: ingeniería geofisica
#   423056: ingeniería geologica
#   431016: matemática (incluye la carrera de matemáticas)
#   431026: matemática aplicada
#   431036: matemática e informatica
#   432016: estadistica
#   432026: estadistica e informatica
#   432036: ingeniería estadistica
#   432046: ingeniería estadistica e informatica
#   433016: investigacion operativa
#   441015: administración de centro de computo
#   441016: ciencias de la computacion
#   441025: administración informatica de empresas
#   441026: ciencias de la informacion
#   441035: administración y sistemas
#   441036: computacion cientifica
#   441045: analisis de sistemas
#   441046: computacion e informatica
#   441055: analisis de sistemas y modelacion de base de datos
#   441056: informatica
#   441065: analista
#   441075: analista programador
#   441085: computacion
#   441095: computacion e informatica
#   441105: computacion y administración de sistemas
#   441115: computacion y sistemas
#   441125: informatica
#   441135: microcomputacion e informatica
#   441145: procesamiento de datos
#   441155: programacion
#   441165: redes y comunicacion de datos
#   441175: redes y comunicaciones
#   441185: redes y seguridad informatica
#   441195: reparacion de computadoras
#   441205: reparacion de computadoras y redes
#   441215: seguridad informatica
#   441225: sistemas de informacion
#   441235: sistemas informaticos para la productividad
#   441245: software y sistemas
#   441255: soporte de sistemas y redes
#   511016: ingeniería de seguridad y auditoria informatica
#   511026: ingeniería de sistemas
#   511036: ingeniería de sistemas de informacion
#   511046: ingeniería de sistemas de informacion y gestion
#   511056: ingeniería de sistemas e informatica (se incluye la carrera de ingeniería informática y de sistemas)
#   511066: ingeniería de sistemas empresariales
#   511076: ing de sistemas y computacion (se incluye la carrera de ing de computación y sistemas e ing de sistemas y cómputo)
#   511086: ingeniería de sistemas y gestion de tecnologias de la informacion
#   511096: ingeniería de sistemas y seguridad informatica
#   511106: ingeniería de sistemas y telematica
#   511116: ingeniería de sistemas y tecnologicas
#   511126: ingeniería de software
#   511136: ingeniería de tecnologias de la informacion y sistemas
#   511146: ingeniería en tecnologias y sistemas de informacion
#   511156: ingeniería informatica
#   511166: ingeniería informatica y estadistica (se incluye la carrera de ingeniería de informática y estadística)
#   512015: control de transito aereo
#   512016: ingeniería de redes y comunicaciones
#   512025: sistemas de telecomunicaciones
#   512026: ingeniería de tecnologias de informacion y comunicacion
#   512035: tecnica en ingeniería de sonidos
#   512036: ingeniería de tecnologias de informacion y sistemas
#   512045: tecnica en ingeniería de telecomunicaciones
#   512046: ingeniería de telecomunicaciones (se incluye la carrera de ing de las telecomunicaciones e ing en telecomunicaciones)
#   512055: tecnica en ingeniería de telematica
#   512056: ingeniería en telecomunicaciones y redes (se incluye la carrera de ingeniería de las telecomunicaciones y redes)
#   512065: telecomunicaciones
#   512066: ingeniería en telecomunicaciones y telematica (se incluye la carrera de ingeniería de telecomunicaciones y telemática)
#   512075: telematica
#   512076: ingeniería en teleinformatica (se incluye la carrera de ingeniería teleinformática)
#   521015: procesos industriales y de sistemas
#   521016: ingeniería ambiental y de prevencion de riesgos
#   521025: salud y seguridad ocupacional
#   527025: explotacion minera
#   527026: ingeniería de minas y maquinaria pesada
#   527035: geologia de minas
#   527036: ingeniería de petroleo
#   527045: laboratorio quimico y metalurgico
#   527046: ingeniería de petroleo y gas natural
#   527055: metalurgia
#   527056: ingeniería metalurgica (incluye la carrera de ingeniería de metalúrgia)
#   527065: modeleria y fundicion
#   527066: ingeniería metalurgica y de materiales (incluye la carrera de ingeniería metalúrgia y de materiales)
#   527075: procesos quimicos y metalurgicos
#   527076: ingeniería petroquimica
#   528015: disenio de modas
#   528016: ingeniería textil
#   528025: disenio de modas y modisteria industrial
#   528026: ingeniería textil y confecciones (incluye la carrera de ingeniería textil y de confecciones)
#   528035: disenio textil
#   528045: disenio y producción de textiles
#   528055: gestion de modas y confecciones
#   528065: gestion de la producción en la industria de las confecciones
#   528075: gestion textil
#   528085: industria del cuero
#   528095: industria del vestido
#   528105: producción textil
#   531015: aerofotografia
#   531016: ingeniería civil
#   531025: construccion civil
#   531026: ingeniería civil y ambiental
#   531035: dibujo en construccion civil
#   531036: ingeniería civil y desarrollo inmobiliario
#   531045: edificaciones
#   531046: ingeniería civil y disenio arquitectonico
#   531055: geomatica
#   531056: ingeniería topografica y agrimensura
#   531065: gestion de la producción en la industria de la construccion
#   531075: laboratorio de suelos, concreto y asfalto
#   531085: suelos, concreto y asfalto
#   531095: topografia
#   531105: topografia superficial y minera
#   532016: ingeniería sanitaria
#   532026: ingeniería sanitaria y ambiental
#   533015: arquitectura de interiores
#   533016: arqueoarquitectura y gestion turistica
#   533026: arquitectura
#   533036: arquitectura de interiores
#   533046: arquitectura del paisaje
#   533056: arquitectura y disenio de interiores
#   533066: arquitectura y gestion de proyectos
#   533076: arquitectura y gestion de territorios
#   533086: arquitectura y territorio
#   533096: arquitectura y urbanismo
#   533106: arquitectura y urbanismo ambiental
#   533116: arquitectura, urbanismo y artes
#   533126: arquitectura, urbanismo y territorio
#   533136: urbanismo
#   534015: conservacion de bienes arqueologicos
#   534025: conservacion y restauracion
#   534035: restauracion de monumentos historicos y bienes inmuebles
#   591015: conduccion de embarcaciones de pesca
#   591016: ingeniería de la producción e industrializacion de recursos hidrobiologicos
#   591025: producción en pesqueria
#   591026: ingeniería pesquera
#   591035: tecnologia pesquera
#   591036: pesqueria
#   592016: ciencias aeronauticas
#   592026: ciencias navales
#   592036: ingeniería aeronautica
#   592046: ingeniería de navegacion y marina mercante
#   592056: ingeniería del transporte maritimo y gestion logistica portuaria
#   592066: ingeniería hidraulica
#   592076: ingeniería maritima
#   592086: ingeniería naval
#   593016: geografia
#   593026: geografia y medio ambiente
#   593036: ingeniería geografica
#   593046: ingeniería geografica y ecologica
#   594015: manejo de cuencas y gestion ambiental
#   594016: ciencia tecnologia y ambiente
#   594025: medio ambiente
#   594026: desarrollo ambiental
#   594035: medio ambiente y recursos naturales
#   594036: ecologia
#   594046: gestion ambiental empresarial
#   594056: ingeniería ambiental
#   594066: ingeniería ambiental y recursos naturales
#   594076: ingeniería de recursos naturales y energias renovables
#   594086: ingeniería de medio ambiente (incluye la carrera de ingeniería ambiental)
#   594096: ingeniería en ecologia de bosques tropicales
#   594106: ingeniería en ecoturismo
#   594116: ingeniería en gestion ambiental (incluye la carrera ingeniería y gestión ambiental)
#   594126: meteorologia
#   599016: ingeniería automotriz
#   599026: ingeniería biomedica
#   599036: ingeniería de disenio grafico
#   599046: ingeniería de transportes
#   611015: administración de negocios agropecuarios
#   611016: agronomia
#   611025: administración rural
#   611026: agronomia tropical
#   611035: agropecuaria
#   611036: ciencias agrarias
#   611045: fruticultura
#   611046: ciencias pecuarias
#   611055: fruticultura y olivicultura
#   611056: conservacion de suelos y agua
#   611065: gestion de recursos hidricos
#   611066: ingeniería agraria
#   611075: horticultura
#   611076: ingeniería agricola
#   611085: jardineria y paisajismo
#   611086: ingeniería agricola y forestal
#   611095: producción agraria
#   611096: ingeniería agroecologica y desarrollo rural (incluye la carrera de agroecológica y desarrollo rural)
#   611105: producción agricola
#   611106: ingeniería agronoma
#   611115: producción agropecuaria
#   611116: ingeniería agronomica
#   611125: producción pecuaria
#   611126: ingeniería agronomica tropical
#   611135: producción y gestion pecuaria
#   611136: ingeniería agropecuaria
#   611145: riego drenaje
#   611146: ingeniería de negocios agronomicos y forestales
#   611155: tecnologia agricola
#   611156: ingeniería en ciencias agrarias
#   612015: administración de recursos forestales
#   612016: ciencias forestales
#   612025: forestal
#   612026: ciencias forestales y del ambiente
#   612035: forestal (para zona de selva)
#   612036: ingeniería agroforestal
#   612046: ingeniería agroforestal acuicola
#   612056: ingeniería forestal
#   612066: ing forestal y del medio ambiente (incluye la carrera de ing forestal y medio ambiente e ing forestal y ambiental)
#   613015: acuicultura
#   613016: acuicultura
#   613026: ingeniería en acuicultura
#   621016: medicina veterinaria
#   621026: veterinaria y zootecnia
#   621036: medicina veterinaria y zootecnia
#   711015: anestesiologia
#   711016: medicina
#   711025: paramedico
#   711026: medicina humana
#   712015: nutricion y dietetica
#   712016: bromatologia y nutricion
#   712025: nutricion y tecnologia de los alimentos
#   712026: ciencias de la nutricion
#   712036: ciencias de los alimentos (incluye la carrera de ciencia de los alimentos)
#   712046: nutricion
#   712056: nutricion humana
#   712066: nutricion, salud y tecnicas alimentarias
#   712076: nutricion y dietetica
#   713015: protesis dental
#   713016: estomatologia
#   713026: odontologia
#   714015: auxiliar de enfermeria
#   714016: enfermeria
#   714025: cuidados auxiliares de enfermeria
#   714035: enfermeria tecnica
#   714045: inyectables y primeros auxilios
#   715015: fisioterapia y rehabilitacion
#   715016: laboratorio clinico
#   715025: laboratorio clinico
#   715026: laboratorio y anatomia patologica
#   715035: mantenimiento de establecimientos de salud
#   715036: optometria
#   715045: optica
#   715046: radiologia
#   715055: optometria
#   715056: tecnologia medica
#   715065: ortopedia
#   715066: terapia de lenguaje
#   715075: radiologia
#   715076: terapia fisica
#   715086: terapia fisica y rehabilitacion
#   715096: terapia ocupacional
#   716015: farmacia
#   716016: ciencias farmaceuticas y bioquimica
#   716026: farmacia y bioquimica
#   716036: toxicologia
#   717015: obstetricia
#   717016: obstetricia
#   717026: obstetricia y puericultura
#   719016: ciencias del deporte
#   811015: conduccion en turismo
#   811025: ecologia turistica
#   811035: guia oficial de caminata
#   811045: guia oficial de montania
#   811055: guia oficial de turismo
#   811065: informacion turistica
#   811075: operaciones de viajes
#   811085: operaciones hoteleras
#   811095: promocion de turismo (incluye la carrera de promoción turística)
#   811105: turismo
#   811115: viajes y turismo
#   812015: cosmetica dermatologica
#   999999: no especificado
# ------------------------------

# %% [markdown]
# ## Seleccionar columnas de interés

# %%
# Cols of interest 1

cols1 = ['aÑo', # año
        'conglome', 'vivienda', 'hogar', 'codperso', # key de persona
        'txt505', # p505 before encoding
        'txt505b', # p505 tasks
        'txt506',
        'p208a', # edad
        'p501',
        'p502',
        'p503',
        'p504',
        'p5041',
        'p5042',
        'p5043',
        'p5044',
        'p5045',
        'p5046',
        'p5047',
        'p5048',
        'p5049',
        'p50410',
        'p50411'
        ] + vars_1

df1 = pd.read_stata(raw_path / 'enaho01a_2020_2024_500_txt.dta', columns=cols1, convert_categoricals=False)

# %%
# Cols of interest 2

cols2 = ['anio', # año
        'conglome', 'vivienda', 'hogar', 'codperso' # key de persona
        ] + vars_2

df2 = pd.read_stata(raw_path / 'enaho01a-2020-2024-300-educacion_p301a.dta', columns=cols2, convert_categoricals=False)
# Out:
# /tmp/ipython-input-43403973.py:7: UnicodeWarning:
# One or more strings in the dta file could not be decoded using utf-8, and
# so the fallback encoding of latin-1 is being used.  This can happen when a file
# has been incorrectly encoded by Stata or some other software. You should verify
# the string values returned are correct.
#   df2 = pd.read_stata(raw_path / 'enaho01a-2020-2024-300-educacion_p301a.dta', columns=cols2, convert_categoricals=False)

# %% [markdown]
# ## Agregando las etiquetas (lbl) como nuevas variables

# %%
df1 = df1.rename(columns={'aÑo': 'anio'})
df1.head(3)
# Out:
#    anio conglome vivienda hogar codperso  \
# 0  2020   005002      011    11       01
# 1  2020   005002      011    11       02
# 2  2020   005002      011    11       03
#
#                                            txt505  \
# 0  TEJEDORA DE CHOMPA DE LANA EN MAQUINA DE TEJER
# 1
# 2                          TECNICO ADMINISTRATIVO
#
#                                     txt505b  p208a  p501  p502  ...  p5048  \
# 0  TEJER CHOMPA DE LANA EN MAQUINA DE TEJER     66   1.0   NaN  ...    NaN
# 1                                               43   2.0   2.0  ...    2.0
# 2         DIGITAR DOCUMENTO MANEJAR SISTEMA     47   1.0   NaN  ...    NaN
#
#    p5049  p50410  p50411  p207  p301a  p506r4  p507  p510  p505r4
# 0    NaN     NaN     NaN     2    4.0  1430.0   2.0   NaN  7351.0
# 1    2.0     2.0     2.0     1    3.0     NaN   NaN   NaN     NaN
# 2    NaN     NaN     NaN     2    8.0  8610.0   3.0   2.0  4419.0
#
# [3 rows x 29 columns]

# %%
df2.head(3)

# %%
# labels
for var, mapping in labels_dict.items():
    if var in df1.columns:
        df1[f'{var}_label'] = df1[var].map(mapping)
    elif var in df2.columns:
        df2[f'{var}_label'] = df2[var].map(mapping)

# %% [markdown]
# ## Convertir archivo .dat a .parquet

# %%
interim_path = Path('/content/drive/MyDrive/PEU - CD/classification_coding_open_ended_occupational_responses_ENAHO/data/interim') # '../data/interim'

# %%
df1.to_parquet(interim_path / 'enaho.parquet', compression='snappy')
df2.to_parquet(interim_path / 'enaho_300.parquet', compression='snappy')

# %%
# Checking parquets

df1 = pd.read_parquet(interim_path / 'enaho.parquet')
df2 = pd.read_parquet(interim_path / 'enaho_300.parquet')

# %%
print(df1.shape)
print(df2.shape)

# %%
print("Columnas df1:", list(df1.columns))
print("Columnas df2:",list(df2.columns))

# %%
print(df1.head(2))

# %%
print(df2.head(2))

# %% [markdown]
# ## Merge de los parquets

# %%
# Merge
df_merged = pd.merge(
    df1,  # left
    df2[['anio', 'conglome', 'vivienda', 'hogar', 'codperso', 'p301a1', 'p301a1_label']],  # right
    on=['anio', 'conglome', 'vivienda', 'hogar', 'codperso'],
    how='left'
)

# %%
print(df_merged.shape)

# %%
print(list(df_merged.columns))

# %%
print(df_merged['p506r4_label'].unique().tolist())

# %%
print(df_merged.dtypes)

# %% [markdown]
# ## Guardar df_merged como un archivo parquet

# %%
df_merged.to_parquet(interim_path / 'enaho_merged.parquet', compression='snappy')

# %%
preview_merged = pd.read_parquet(interim_path / 'enaho_merged.parquet')

# %%
preview_merged.shape

# %%
list(preview_merged.columns)

# %%
# preview_merged.head(50)
# Out:
#     anio conglome vivienda hogar codperso  \
# 0   2020   005002      011    11       01
# 1   2020   005002      011    11       02
# 2   2020   005002      011    11       03
# 3   2020   005002      023    11       01
# 4   2020   005002      049    11       01
# 5   2020   005002      049    11       02
# 6   2020   005002      049    11       03
# 7   2020   005002      049    11       04
# 8   2020   005002      073    11       01
# 9   2020   005002      073    11       02
# 10  2020   005002      097    11       01
# 11  2020   005005      009    11       01
# 12  2020   005005      009    11       02
# 13  2020   005005      009    11       03
# 14  2020   005005      014    11       01
# 15  2020   005005      027    11       01
# 16  2020   005005      033    11       01
# 17  2020   005005      033    11       02
# 18  2020   005005      033    11       03
# 19  2020   005005      037    11       01
# 20  2020   005005      037    11       02
# 21  2020   005005      037    11       03
# 22  2020   005005      041    11       01
# 23  2020   005005      041    11       02
# 24  2020   005005      041    11       03
# 25  2020   005005      041    11       04
# 26  2020   005005      041    11       09
# 27  2020   005005      041    11       10
# 28  2020   005005      041    11       12
# 29  2020   005005      043    11       01
# 30  2020   005005      043    11       02
# 31  2020   005005      043    11       03
# 32  2020   005005      050    11       01
# 33  2020   005007      003    11       01
# 34  2020   005007      012    11       01
# 35  2020   005007      022    11       01
# 36  2020   005007      022    11       02
# 37  2020   005007      022    11       03
# 38  2020   005007      050    11       01
# 39  2020   005007      050    11       02
# 40  2020   005009      012    11       01
# 41  2020   005009      012    11       02
# 42  2020   005009      041    11       01
# 43  2020   005009      041    11       02
# 44  2020   005009      098    11       01
# 45  2020   005009      098    11       02
# 46  2020   005009      098    11       03
# 47  2020   005009      098    11       04
# 48  2020   005009      098    11       05
# 49  2020   005010      009    11       01
#
#                                                txt505  \
# 0      TEJEDORA DE CHOMPA DE LANA EN MAQUINA DE TEJER
# 1
# 2                              TECNICO ADMINISTRATIVO
# 3                                CARPINTERO EN MADERA
# 4
# 5
# 6                                     PINTOR DE PARED
# 7                             SUPERVISORA DE ENCUESTA
# 8
# 9
# 10
# 11                                CHOFER DE CAMIONETA
# 12
# 13
# 14                           ELECTRICISTA DE VEHICULO
# 15
# 16
# 17
# 18
# 19                               PERSONAL DE LIMPIEZA
# 20
# 21
# 22
# 23                               PERSONAL DE LIMPIEZA
# 24                                       FOTOCOPIADOR
# 25                OPERADOR DE MAQUINA RETROEXCAVADORA
# 26
# 27              PROFESOR DE ARTE Y CULTURA SECUNDARIA
# 28
# 29                               PEON EN CONSTRUCCION
# 30
# 31                             SUB OFICIAL DE TERCERA
# 32    VENDEDORA DE FRUTA GOLOSINA TUBERCULO POR MENOR
# 33              DIRECTOR DE AREA DE CALIDAD EDUCATIVA
# 34                                 AYUDANTE DE COCINA
# 35                                     ADMINISTRACION
# 36                           ASISTENTE ADMINISTRATIVO
# 37                       ADMINISTRADOR EN RESTAURANTE
# 38
# 39
# 40  PREPARADORA VENDEDORA DE COMIDA GOLOSINA GASEO...
# 41  AYUDANTE DE PREPARADORA VENDEDORA DE COMIDA GO...
# 42  VENDEDORA DE ABARROTE FRUTA PAN PAPA CERVEZA G...
# 43                                             NIÑERA
# 44
# 45        TEJEDORA DE COLCHA DE LANA A CROCHET A MANO
# 46                            PERSONAL ADMINISTRACION
# 47
# 48
# 49                              PERSONAL DE SEGURIDAD
#
#                                               txt505b  p208a  p501  p502  ...  \
# 0            TEJER CHOMPA DE LANA EN MAQUINA DE TEJER     66   1.0   NaN  ...
# 1                                                         43   2.0   2.0  ...
# 2                   DIGITAR DOCUMENTO MANEJAR SISTEMA     47   1.0   NaN  ...
# 3   CONFECCIONAR LAQUEAR PUERTA VENTANA CAMA DE MA...     62   1.0   NaN  ...
# 4                                                         74   2.0   2.0  ...
# 5                                                         73   2.0   2.0  ...
# 6                            PINTAR PARED CON RODILLO     51   1.0   NaN  ...
# 7   SUPERVISAR EJECUCION DE ENCUESTA REVISAR INFOR...     48   1.0   NaN  ...
# 8                                                         60   2.0   2.0  ...
# 9                                                         58   2.0   2.0  ...
# 10                                                        80   2.0   2.0  ...
# 11          TRANSPORTAR PERSONAL DE GOBIERNO REGIONAL     57   2.0   1.0  ...
# 12                                                        54   2.0   2.0  ...
# 13                                                        19   2.0   2.0  ...
# 14              REPARAR SISTEMA ELECTRICO DE VEHICULO     53   1.0   NaN  ...
# 15                                                        54   2.0   2.0  ...
# 16                                                        76   2.0   2.0  ...
# 17                                                        72   2.0   2.0  ...
# 18                                                        51   2.0   2.0  ...
# 19  LIMPIAR OFICINA DESINFECTAR MUEBLE SERVICIO HI...     46   1.0   NaN  ...
# 20                                                        23   2.0   2.0  ...
# 21                                                        17   2.0   2.0  ...
# 22                                                        53   2.0   2.0  ...
# 23  REALIZAR LIMPIEZA DE OFICINA DESINFECTAR MOVIL...     47   1.0   NaN  ...
# 24  ATENDER CLIENTE SACAR FOTOCOPIA IMPRESION VEND...     29   1.0   NaN  ...
# 25                     OPERAR MAQUINA RETROEXCAVADORA     29   1.0   NaN  ...
# 26                                                        24   2.0   2.0  ...
# 27  PREPARAR ENVIAR FICHA DE TRABAJO MONITOREAR A ...     32   1.0   NaN  ...
# 28                                                        76   2.0   2.0  ...
# 29                     ARMAR LLENAR TECHO DE CONCRETO     47   1.0   NaN  ...
# 30                                                        46   2.0   2.0  ...
# 31  REALIZAR PATRULLAJE A PIE CONTROLAR EL CUMPLIM...     20   1.0   NaN  ...
# 32                    ATENDER CLIENTE VENDER PRODUCTO     68   1.0   NaN  ...
# 33  ACREDITAR PROCESO ACADEMICO GESTIONAR CONDICIO...     55   1.0   NaN  ...
# 34       PICAR VERDURA PREPARAR ENSALADA SERVIR PLATO     20   1.0   NaN  ...
# 35             RECEPCIONAR DOCUMENTACION VERIFICACION     61   1.0   NaN  ...
# 36  GESTIONAR LLAMADA CORREO ELECTRÓNICO REDACTAR ...     60   1.0   NaN  ...
# 37  PLANIFICAR ORGANIZAR DIRIGIR OPERATIVIDAD DE R...     28   1.0   NaN  ...
# 38                                                        87   2.0   2.0  ...
# 39                                                        78   2.0   2.0  ...
# 40  PREPARACION DE COMIDA ATENDER CLIENTE VENDER P...     49   1.0   NaN  ...
# 41                    ATENDER CLIENTE VENDER PRODUCTO     16   1.0   NaN  ...
# 42        VENDER PRODUCTO A CLIENTE COBRAR DAR VUELTO     61   1.0   NaN  ...
# 43             ATENDER A NIÑA BRINDAR ALIMENTO A NIÑA     29   1.0   NaN  ...
# 44                                                        59   2.0   2.0  ...
# 45      OVILLAR MADEJA DE LANA TEJER COLCHA A CROCHET     42   1.0   NaN  ...
# 46       REDACTAR RECIBIR DOCUMENTO ATENDER A PUBLICO     20   1.0   NaN  ...
# 47                                                        18   2.0   2.0  ...
# 48                                                        16   2.0   2.0  ...
# 49  RESGUARDAR INSTITUCION BIEN PATRIMONIAL REGIST...     53   1.0   NaN  ...
#
#     p510  p505r4  p207_label                           p301a_label  \
# 0    NaN  7351.0       mujer                     primaria completa
# 1    NaN     NaN      hombre                   primaria incompleta
# 2    2.0  4419.0       mujer    superior no universitaria completa
# 3    NaN  7322.0      hombre                   secundaria completa
# 4    NaN     NaN      hombre                   secundaria completa
# 5    NaN     NaN       mujer                     primaria completa
# 6    NaN  7128.0      hombre                   secundaria completa
# 7    2.0  4225.0       mujer       superior universitaria completa
# 8    NaN     NaN      hombre                   secundaria completa
# 9    NaN     NaN       mujer                     primaria completa
# 10   NaN     NaN       mujer                   primaria incompleta
# 11   2.0  8322.0      hombre                   secundaria completa
# 12   NaN     NaN       mujer                   secundaria completa
# 13   NaN     NaN       mujer     superior universitaria incompleta
# 14   6.0  7231.0      hombre                   secundaria completa
# 15   NaN     NaN       mujer  superior no universitaria incompleta
# 16   NaN     NaN      hombre                   primaria incompleta
# 17   NaN     NaN       mujer                   primaria incompleta
# 18   NaN     NaN       mujer                   primaria incompleta
# 19   5.0  9112.0       mujer  superior no universitaria incompleta
# 20   NaN     NaN       mujer       superior universitaria completa
# 21   NaN     NaN       mujer     superior universitaria incompleta
# 22   NaN     NaN      hombre                 secundaria incompleta
# 23   5.0  9112.0       mujer  superior no universitaria incompleta
# 24   NaN  4419.0       mujer    superior no universitaria completa
# 25   2.0  8343.0      hombre                   secundaria completa
# 26   NaN     NaN       mujer     superior universitaria incompleta
# 27   6.0  2330.0      hombre    superior no universitaria completa
# 28   NaN     NaN       mujer                             sin nivel
# 29   6.0  9313.0      hombre                   secundaria completa
# 30   NaN     NaN       mujer                     primaria completa
# 31   1.0   220.0      hombre    superior no universitaria completa
# 32   NaN  5212.0       mujer                   primaria incompleta
# 33   2.0  1114.0      hombre                    maestria/doctorado
# 34   6.0  9412.0       mujer                   secundaria completa
# 35   2.0  4419.0      hombre  superior no universitaria incompleta
# 36   2.0  4419.0       mujer    superior no universitaria completa
# 37   6.0  3314.0      hombre       superior universitaria completa
# 38   NaN     NaN      hombre                     primaria completa
# 39   NaN     NaN       mujer                     primaria completa
# 40   NaN  5120.0       mujer                   secundaria completa
# 41   NaN  9412.0       mujer                   secundaria completa
# 42   NaN  5212.0       mujer                             sin nivel
# 43   NaN  9111.0       mujer       superior universitaria completa
# 44   NaN     NaN      hombre                 secundaria incompleta
# 45   NaN  7351.0       mujer                   secundaria completa
# 46   2.0  4419.0       mujer    superior no universitaria completa
# 47   NaN     NaN      hombre     superior universitaria incompleta
# 48   NaN     NaN       mujer                 secundaria incompleta
# 49   2.0  9622.0       mujer    superior no universitaria completa
#
#                                          p506r4_label  \
# 0   fabricaciÃ³n de prendas de tejidos de punto y ...
# 1                                                None
# 2                           actividades de hospitales
# 3                             fabricaciÃ³n de muebles
# 4                                                None
# 5                                                None
# 6                 terminaciÃ³n y acabado de edificios
# 7   actividades de la administraciÃ³n pÃºblica en ...
# 8                                                None
# 9                                                None
# 10                                               None
# 11  actividades de la administraciÃ³n pÃºblica en ...
# 12                                               None
# 13                                               None
# 14  mantenimiento y reparaciÃ³n de vehÃ­culos auto...
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19  otras actividades de limpieza en edificios e i...
# 20                                               None
# 21                                               None
# 22                                               None
# 23  otras actividades de limpieza en edificios e i...
# 24  fotocopiado, preparaciÃ³n de documentos y otra...
# 25  regulaciÃ³n y facilitaciÃ³n de la actividad ec...
# 26                                               None
# 27        enseÃ±anza secundaria de formaciÃ³n general
# 28                                               None
# 29                         construcciÃ³n de edificios
# 30                                               None
# 31  actividades de mantenimiento del orden pÃºblic...
# 32  venta al por menor de alimentos en almacenes e...
# 33                                enseÃ±anza superior
# 34  restaurantes y servicios mÃ³viles de alimentac...
# 35  regulaciÃ³n y facilitaciÃ³n de la actividad ec...
# 36  regulaciÃ³n de las act de organis que prestan ...
# 37  restaurantes y servicios mÃ³viles de alimentac...
# 38                                               None
# 39                                               None
# 40  restaurantes y servicios mÃ³viles de alimentac...
# 41  restaurantes y servicios mÃ³viles de alimentac...
# 42  venta al por menor de alimentos en almacenes e...
# 43  actividades de los hogares en calidad de emple...
# 44                                               None
# 45  fabricaciÃ³n de artÃ­culos confeccionados con ...
# 46  regulaciÃ³n y facilitaciÃ³n de la actividad ec...
# 47                                               None
# 48                                               None
# 49                                enseÃ±anza superior
#
#                            p507_label  \
# 0            trabajador independiente
# 1                                None
# 2                            empleado
# 3                 empleador o patrono
# 4                                None
# 5                                None
# 6            trabajador independiente
# 7                            empleado
# 8                                None
# 9                                None
# 10                               None
# 11                             obrero
# 12                               None
# 13                               None
# 14                             obrero
# 15                               None
# 16                               None
# 17                               None
# 18                               None
# 19                             obrero
# 20                               None
# 21                               None
# 22                               None
# 23                             obrero
# 24           trabajador independiente
# 25                             obrero
# 26                               None
# 27                           empleado
# 28                               None
# 29                             obrero
# 30                               None
# 31                           empleado
# 32           trabajador independiente
# 33                           empleado
# 34                             obrero
# 35                           empleado
# 36                           empleado
# 37                           empleado
# 38                               None
# 39                               None
# 40           trabajador independiente
# 41  trabajador familiar no remunerado
# 42           trabajador independiente
# 43               trabajador del hogar
# 44                               None
# 45           trabajador independiente
# 46                           empleado
# 47                               None
# 48                               None
# 49                             obrero
#
#                                            p510_label  \
# 0                                                None
# 1                                                None
# 2                            administraciÃ³n pÃºblica
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                            administraciÃ³n pÃºblica
# 8                                                None
# 9                                                None
# 10                                               None
# 11                           administraciÃ³n pÃºblica
# 12                                               None
# 13                                               None
# 14                          empresa o patrono privado
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19         empresas especiales de servicios (service)
# 20                                               None
# 21                                               None
# 22                                               None
# 23         empresas especiales de servicios (service)
# 24                                               None
# 25                           administraciÃ³n pÃºblica
# 26                                               None
# 27                          empresa o patrono privado
# 28                                               None
# 29                          empresa o patrono privado
# 30                                               None
# 31  fuerzas armadas, policÃ­a nacional del perÃº (...
# 32                                               None
# 33                           administraciÃ³n pÃºblica
# 34                          empresa o patrono privado
# 35                           administraciÃ³n pÃºblica
# 36                           administraciÃ³n pÃºblica
# 37                          empresa o patrono privado
# 38                                               None
# 39                                               None
# 40                                               None
# 41                                               None
# 42                                               None
# 43                                               None
# 44                                               None
# 45                                               None
# 46                           administraciÃ³n pÃºblica
# 47                                               None
# 48                                               None
# 49                           administraciÃ³n pÃºblica
#
#                                          p505r4_label    p301a1  \
# 0                       tejedores a mano y en telares       NaN
# 1                                                None       NaN
# 2               otro personal de apoyo administrativo  342025.0
# 3                                  ebanistas y afines       NaN
# 4                                                None       NaN
# 5                                                None       NaN
# 6                            pintores de brocha gorda       NaN
# 7   entrevistadores de encuestas y de investigacio...  522016.0
# 8                                                None       NaN
# 9                                                None       NaN
# 10                                               None       NaN
# 11    conductores de automÃ³viles, taxis y camionetas       NaN
# 12                                               None       NaN
# 13                                               None       NaN
# 14    mecÃ¡nicos y reparadores de vehÃ­culos de motor       NaN
# 15                                               None       NaN
# 16                                               None       NaN
# 17                                               None       NaN
# 18                                               None       NaN
# 19  limpiadores y asistentes de oficinas, hoteles ...       NaN
# 20                                               None       NaN
# 21                                               None       NaN
# 22                                               None       NaN
# 23  limpiadores y asistentes de oficinas, hoteles ...       NaN
# 24              otro personal de apoyo administrativo       NaN
# 25  operadores de grÃºas, aparatos elevadores y af...       NaN
# 26                                               None       NaN
# 27                profesores de enseÃ±anza secundaria       NaN
# 28                                               None       NaN
# 29            peones de la construcciÃ³n de edificios       NaN
# 30                                               None       NaN
# 31               suboficiales de la policÃ­a nacional       NaN
# 32  vendedores minoristas en tiendas y establecimi...       NaN
# 33          directivos de la administraciÃ³n pÃºblica  421026.0
# 34                                ayudantes de cocina       NaN
# 35              otro personal de apoyo administrativo  322055.0
# 36              otro personal de apoyo administrativo  342025.0
# 37                       tÃ©cnicos en administraciÃ³n  322026.0
# 38                                               None       NaN
# 39                                               None       NaN
# 40                                          cocineros       NaN
# 41                                ayudantes de cocina       NaN
# 42  vendedores minoristas en tiendas y establecimi...       NaN
# 43               limpiadores y asistentes domÃ©sticos  332336.0
# 44                                               None       NaN
# 45                      tejedores a mano y en telares       NaN
# 46              otro personal de apoyo administrativo  337025.0
# 47                                               None  321026.0
# 48                                               None       NaN
# 49                      porteros, guardianes y afines  714035.0
#
#                    p301a1_label
# 0                          None
# 1                          None
# 2                  contabilidad
# 3                          None
# 4                          None
# 5                          None
# 6                          None
# 7       industrias alimentarias
# 8                          None
# 9                          None
# 10                         None
# 11                         None
# 12                         None
# 13                         None
# 14                         None
# 15                         None
# 16                         None
# 17                         None
# 18                         None
# 19                         None
# 20                         None
# 21                         None
# 22                         None
# 23                         None
# 24                         None
# 25                         None
# 26                         None
# 27                         None
# 28                         None
# 29                         None
# 30                         None
# 31                         None
# 32                         None
# 33                       fisica
# 34                         None
# 35         periodismo deportivo
# 36                 contabilidad
# 37                   periodismo
# 38                         None
# 39                         None
# 40                         None
# 41                         None
# 42                         None
# 43          turismo y hoteleria
# 44                         None
# 45                         None
# 46       secretariado ejecutivo
# 47  ciencias de la comunicacion
# 48                         None
# 49           enfermeria tecnica
#
# [50 rows x 26 columns]

# %% [markdown]
# # ---
# ---

# %%
# preview_hugo = pd.read_stata('/content/drive/MyDrive/PEU - CD/classification_coding_open_ended_occupational_responses_ENAHO/data/raw/BASE_ENAHO_2020_2024_PLN_FINAL.dta', convert_categoricals=False)

# %%
preview_hugo.shape

# %%
preview_hugo.head(2)

# %% [markdown]
# ---

# %%
# import pandas as pd
# import pyreadstat
# import chardet
# from pathlib import Path

# # Ruta del archivo original
# file_path = Path('/content/drive/MyDrive/PEU - CD/classification_coding_open_ended_occupational_responses_ENAHO/data/raw/enaho01a_2020_2024_500_txt.dta')

# %%
# # --- 1. Detectar encoding automáticamente ---
# with open(file_path, 'rb') as f:
#     raw_data = f.read(100000)  # muestra inicial (100KB)
#     detected = chardet.detect(raw_data)
# encoding_detected = detected['encoding']
# print(f"Encoding detectado: {encoding_detected}")

# %%
# # --- 2. Intentar lectura robusta ---
# try:
#     df, meta = pyreadstat.read_dta(file_path, encoding=encoding_detected)
# except UnicodeDecodeError:
#     print("Error al leer con el encoding detectado. Intentando con 'latin1'...")
#     df, meta = pyreadstat.read_dta(file_path, encoding='latin1')
# except Exception as e:
#     print("Error general:", e)
#     raise

# %%
# # --- 3. Corrección de caracteres mal decodificados (si hubiera) ---
# def fix_encoding(col):
#     def try_fix(x):
#         if isinstance(x, str):
#             try:
#                 return x.encode('latin1').decode('utf-8')
#             except UnicodeEncodeError:
#                 return x
#             except UnicodeDecodeError:
#                 return x
#         return x
#     return col.apply(try_fix)

# for c in df.select_dtypes('object').columns:
#     df[c] = fix_encoding(df[c])

# # --- 4. Guardar en parquet con compresión snappy ---
# out_path = file_path.with_suffix('.parquet')
# df.to_parquet(out_path, compression='snappy')
# print(f"Archivo guardado correctamente en: {out_path}")
